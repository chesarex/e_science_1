# %% [markdown]
# # Tópicos de e-Science

# %% [markdown]
# Estudante: Cesar Augusto H. Condori

# %% [markdown]
# ###### Este  trabalho consiste  em o processamento de dois aquivos com estensão .FITS. O contendo de  estos dois aquivos  1.fits e 2.fits  é  desconhecido.
# Sendo assim o primeiro passo consiste  em ver o  conteudo de estos dois  arquivos.

# %% [markdown]
# ###### IMPORTAR ARQUIVOS 1.fits E 2.fits

# %% [markdown]
# 'Importamos todos os pacotes necesario'

# %%
# %matplotlib inline
import pyfits
from astropy.io import fits
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#aquivo de entrada
hdulist_1 = pyfits.open('1.fits')
hdulist_1.info()
# Out:
# Filename: 1.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     179   ()
# 1    SCI         ImageHDU        71   (6218, 4608)   float32

# %% [markdown]
# * Como se pode  observar  o conteudo  do arquivo '1.fits' é  uma imagnem de (6218, 4608) pixels

# %% [markdown]
# Agora  podemos  ver também qual é  conteudo  do arquivo '2.fits'

# %%
# %matplotlib inline
hdulist_2 = pyfits.open('2.fits')
hdulist_2.info()
#para ver o cabecalho e a dimensao o aquivos filho
# Out:
# Filename: 2.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     179   ()
# 1    MDF         BinTableHDU    158   16R x 25C    [1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 2A, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 9A, 1J, 1J, 1J, 1J, 1J]
# 2    SCI         ImageHDU        71   (3108,)      float32
# 3    SCI         ImageHDU        71   (3108,)      float32
# 4    SCI         ImageHDU        71   (3108,)      float32
# 5    SCI         ImageHDU        71   (3108,)      float32
# 6    SCI         ImageHDU        71   (3108,)      float32
# 7    SCI         ImageHDU        71   (3108,)      float32
# 8    SCI         ImageHDU        71   (3108,)      float32
# 9    SCI         ImageHDU        71   (3108,)      float32
# 10   SCI         ImageHDU        71   (3108,)      float32
# 11   SCI         ImageHDU        71   (3108,)      float32
# 12   SCI         ImageHDU        71   (3108,)      float32
# 13   SCI         ImageHDU        71   (3108,)      float32
# 14   SCI         ImageHDU        71   (3108,)      float32

# %% [markdown]
# ** Como se pode observar acima o arquivo '2.fits' comtem tabelas. Aqui  0 = É  o  cabeçalho do aquivo 2.fits, e os outros (2-14) são  dados.

# %% [markdown]
# Agora podemos  ver  com mais  detalhe  o conteúdo dos arquivos  vendo o header

# %%
# %matplotlib inline
#header o arquivo 1.fits
hdulist_1[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 6218 / Axis length
# NAXIS2  =                 4608 / Axis length
# PCOUNT  =                    0 / No 'random' parameters
# GCOUNT  =                    1 / Only one group
# EXTNAME = 'SCI     '           / Extension name
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 1999' / FITS file originator
# INHERIT =                    F / Inherits global header
# OBJECT  = 'NGC6940 '           / Name of the object observed
# DATE    = '2002-04-19T02:59:34' / Date FITS file was generated
# IRAF-TLM= '16:52:34 (18/04/2002)' / Time of last modification
# CTYPE1  = 'RA---TAN'           / R.A. in tangent plane projection
# CTYPE2  = 'DEC--TAN'           / DEC. in tangent plane projection
# CRPIX1  =      3066.6094105701 / Ref pix of axis 1
# CRPIX2  =     2289.53837129636 / Ref pix of axis 2
# CRVAL1  =     308.606956999258 / RA at Ref pix in decimal degrees
# CRVAL2  =     28.2755603239176 / DEC at Ref pix in decimal degrees
# CD1_1   = -2.0203886051489E-05 / WCS matrix element 1 1
# CD1_2   =  1.7574964632256E-08 / WCS matrix element 1 2
# CD2_1   = 2.34866671962205E-08 / WCS matrix element 2 1
# CD2_2   = 2.02198394066576E-05 / WCS matrix element 2 2
# CCDSUM  = '1 1     '           / CCD sum
# GAIN    =                   4. / Amplifier gain
# RDNOISE =                  6.6 / Readout noise
# GEM-TLM = 'Thu Apr 18 15:46:58 HST 2002' / Last modification with GEMINI
# IMCOADD = 'Thu Apr 18 15:46:58 HST 2002' / Time stamp for imcoadd
# MED_SKY =             355.0512 / Median sky level
# RELINT  =                   1. / Inverse of the relative intensity
# NCOMBINE=                    4
# GAINORIG=                   1. / Input gain
# RONORIG =                  3.3 / Input read-noise
# GEMSEE  = 'Thu Apr 18 16:59:07 HST 2002' / Time stamp for gemseeing
# SEEPRG  = 'gemseeing:  psfmeasure  direct/eed50/eed85/moffat'
# FWHMPSF =     0.69675680994987 / FWHM of PSF [arcsec], direct measurement
# NPSF    =                   10 / Number of stars used by gemseeing
# MFWHM   =     0.68697866797447 / FWHM of PSF [arcsec], Moffat fit
# EED50   =     0.80537062883377 / 50-percent encircled energy diameter [arcsec]
# EED85   =      1.5567978024483 / 85-percent encircled energy diameter [arcsec]
# EPSPSF  =    0.044999999925494 / Ellipticity of PSF
# POSPSF  =                 -17. / Position angle of PSF, CCW from X-axis

# %%
# %matplotlib inline
#header o arquivo 2.fits
hdulist_2[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  103 / width of table in bytes
# NAXIS2  =                   16
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   25
# TTYPE1  = 'ID      '           / label for field   1
# TFORM1  = '1J      '           / data format of field: 4-byte INTEGER
# TUNIT1  = '#       '           / physical unit of field
# TTYPE2  = 'RA      '           / label for field   2
# TFORM2  = '1E      '           / data format of field: 4-byte REAL
# TUNIT2  = 'deg     '           / physical unit of field
# TTYPE3  = 'DEC     '           / label for field   3
# TFORM3  = '1E      '           / data format of field: 4-byte REAL
# TUNIT3  = 'deg     '           / physical unit of field
# TTYPE4  = 'x_ccd   '           / label for field   4
# TFORM4  = '1E      '           / data format of field: 4-byte REAL
# TUNIT4  = 'pixels  '           / physical unit of field
# TTYPE5  = 'y_ccd   '           / label for field   5
# TFORM5  = '1E      '           / data format of field: 4-byte REAL
# TUNIT5  = 'pixels  '           / physical unit of field
# TTYPE6  = 'slitpos_x'          / label for field   6
# TFORM6  = '1E      '           / data format of field: 4-byte REAL
# TUNIT6  = 'arcsec  '           / physical unit of field
# TTYPE7  = 'slitpos_y'          / label for field   7
# TFORM7  = '1E      '           / data format of field: 4-byte REAL
# TUNIT7  = 'arcsec  '           / physical unit of field
# TTYPE8  = 'slitsize_x'         / label for field   8
# TFORM8  = '1E      '           / data format of field: 4-byte REAL
# TUNIT8  = 'arcsec  '           / physical unit of field
# TTYPE9  = 'slitsize_y'         / label for field   9
# TFORM9  = '1E      '           / data format of field: 4-byte REAL
# TUNIT9  = 'arcsec  '           / physical unit of field
# TTYPE10 = 'slittilt'           / label for field  10
# TFORM10 = '1E      '           / data format of field: 4-byte REAL
# TUNIT10 = 'deg     '           / physical unit of field
# TTYPE11 = 'priority'           / label for field  11
# TFORM11 = '2A      '           / data format of field: ASCII Character
# TUNIT11 = 'c       '           / physical unit of field
# TTYPE12 = 'slitpos_mx'         / label for field  12
# TFORM12 = '1E      '           / data format of field: 4-byte REAL
# TTYPE13 = 'slitpos_my'         / label for field  13
# TFORM13 = '1E      '           / data format of field: 4-byte REAL
# TTYPE14 = 'slitid  '           / label for field  14
# TFORM14 = '1E      '           / data format of field: 4-byte REAL
# TTYPE15 = 'slitsize_mx'        / label for field  15
# TFORM15 = '1E      '           / data format of field: 4-byte REAL
# TTYPE16 = 'slitsize_my'        / label for field  16
# TFORM16 = '1E      '           / data format of field: 4-byte REAL
# TTYPE17 = 'slittilt_m'         / label for field  17
# TFORM17 = '1E      '           / data format of field: 4-byte REAL
# TTYPE18 = 'slitsize_mr'        / label for field  18
# TFORM18 = '1E      '           / data format of field: 4-byte REAL
# TTYPE19 = 'slitsize_mw'        / label for field  19
# TFORM19 = '1E      '           / data format of field: 4-byte REAL
# TTYPE20 = 'slittype'           / label for field  20
# TFORM20 = '9A      '           / data format of field: ASCII Character
# TTYPE21 = 'SELECT  '           / label for field  21
# TFORM21 = '1J      '           / data format of field: 4-byte INTEGER
# TTYPE22 = 'SECX1   '           / label for field  22
# TFORM22 = '1J      '           / data format of field: 4-byte INTEGER
# TTYPE23 = 'SECX2   '           / label for field  23
# TFORM23 = '1J      '           / data format of field: 4-byte INTEGER
# TTYPE24 = 'SECY1   '           / label for field  24
# TFORM24 = '1J      '           / data format of field: 4-byte INTEGER
# TTYPE25 = 'SECY2   '           / label for field  25
# TFORM25 = '1J      '           / data format of field: 4-byte INTEGER
# TDISP1  = 'I6      '           / display format
# TNULL1  =          -2147483647 / undefined value for column
# TDISP2  = 'F13.3   '           / display format
# TDISP3  = 'F13.3   '           / display format
# TDISP4  = 'F13.3   '           / display format
# TDISP5  = 'F13.3   '           / display format
# TDISP6  = 'F13.3   '           / display format
# TDISP7  = 'F13.3   '           / display format
# TDISP8  = 'F13.3   '           / display format
# TDISP9  = 'F13.3   '           / display format
# TDISP10 = 'F13.3   '           / display format
# TDISP11 = 'A10     '           / display format
# TDISP12 = 'F9.6    '           / display format
# TDISP13 = 'F9.6    '           / display format
# TDISP14 = 'I4      '           / display format
# TDISP15 = 'F8.6    '           / display format
# TDISP16 = 'F8.6    '           / display format
# TDISP17 = 'F6.3    '           / display format
# TDISP18 = 'F8.6    '           / display format
# TDISP19 = 'F8.6    '           / display format
# TDISP20 = 'A9      '           / display format
# TDISP21 = 'I11     '           / display format
# TNULL21 =          -2147483647 / undefined value for column
# TDISP22 = 'I11     '           / display format
# TNULL22 =          -2147483647 / undefined value for column
# TDISP23 = 'I11     '           / display format
# TNULL23 =          -2147483647 / undefined value for column
# TDISP24 = 'I11     '           / display format
# TNULL24 =          -2147483647 / undefined value for column
# TDISP25 = 'I11     '           / display format
# TNULL25 =          -2147483647 / undefined value for column
# EXTNAME = 'MDF     '           / MASTER OBJECT TABLE EXTENSION
#
#
#
#
#
#
#
#
#
#
# IRAF    = 'NOAO/IRAFV2.11.3EXPORT'
# USER    = 'dataproc'
# HOST    = 'draco   '
# DATE    = '2001-08-17'
# TIME    = '02:09:49'
# PACKAGE = 'apphot  '
# TASK    = 'daofind '
# SCALE   =                   1.
# FWHMPSF =                   9.
# EMISSION=                    F
# DATAMIN =                 100.
# DATAMAX =               40000.
# EXPOSURE= '        '
# AIRMASS = '        '
# FILTER  = 'r_G0303 '
# OBSTIME = '        '
# NOISE   = 'poisson '
# SIGMA   =                   5.
# GAIN    = '        '
# EPADU   =                  8.8
# CCDREAD = '        '
# READNOIS=                   7.
# IMAGE   = 'grgN20010813S106_add[1]'
# THRESHOL=                 100.
# NSIGMA  =                  1.5
# RATIO   =                   1.
# THETA   =                   0.
# SHARPLO =                  0.2
# SHARPHI =                   1.
# ROUNDLO =                  -1.
# ROUNDHI =                   1.
# PID_IMAG= 'GN-ENG20010804-8'
# PI_IMAG = 'Gemini  '
# DATEIMAG= '2001-08-14'
# TIMEIMAG=             12.13642
# RA_IMAG =         308.60704167
# DEC_IMAG=          28.27555556
# ADCMODE = 'no-correction'
# PID_SPEC= 'GN-ENG200108'
# PI_SPEC = 'Gemini  '
# DATE_OT = '2001-08-16'
# TIME_OT =                  16.
# PERS_OT = 'Jorgensen'
# EXTSOFT = 'apphot/daofind'
# GEMSOFT = 'Gemini IRAF package gmos v0.1'
# INSTRUME= 'GMOS-N  '
# EXTVER  =                    1

# %% [markdown]
# ** Onde ID = o nome  do objeto , RA = acensão reta, e DEC = declinação. Seguidamente podemos ver RA e DEC do OPEN CLUSTER, e de cada objeto

# %%
# %matplotlib inline
print 'OPEN_CLUSTER:             ',hdulist_2[0].header['OBJECT']
print 'OPEN_CLUSTER_Acencao reta:',hdulist_2[0].header['RA']
print 'OPEN_CLUSTER_Declinacao:  ',hdulist_2[0].header['DEC']
print 'Frame:     		 ',hdulist_2[0].header['FRAME']
# Out:
# OPEN_CLUSTER:              NGC6940
# OPEN_CLUSTER_Acencao reta: 308.60704167
# OPEN_CLUSTER_Declinacao:   28.27555556
# Frame:     		  FK5

# %%
# %matplotlib inline

#para  ver o nome das colunas
cols = hdulist_2[1].columns
print cols
#extraindo dados
data1 = hdulist_2[1].data

print 'Objecto:     ',data1.ID
print 'RA:          ',data1.RA
print 'DEC:         ',data1.DEC
# Out:
# ColDefs(
#     name = 'ID'; format = '1J'; unit = '#'; null = -2147483647; disp = 'I6'
#     name = 'RA'; format = '1E'; unit = 'deg'; disp = 'F13.3'
#     name = 'DEC'; format = '1E'; unit = 'deg'; disp = 'F13.3'
#     name = 'x_ccd'; format = '1E'; unit = 'pixels'; disp = 'F13.3'
#     name = 'y_ccd'; format = '1E'; unit = 'pixels'; disp = 'F13.3'
#     name = 'slitpos_x'; format = '1E'; unit = 'arcsec'; disp = 'F13.3'
#     name = 'slitpos_y'; format = '1E'; unit = 'arcsec'; disp = 'F13.3'
#     name = 'slitsize_x'; format = '1E'; unit = 'arcsec'; disp = 'F13.3'
#     name = 'slitsize_y'; format = '1E'; unit = 'arcsec'; disp = 'F13.3'
#     name = 'slittilt'; format = '1E'; unit = 'deg'; disp = 'F13.3'
#     name = 'priority'; format = '2A'; unit = 'c'; disp = 'A10'
#     name = 'slitpos_mx'; format = '1E'; disp = 'F9.6'
#     name = 'slitpos_my'; format = '1E'; disp = 'F9.6'
#     name = 'slitid'; format = '1E'; disp = 'I4'
#     name = 'slitsize_mx'; format = '1E'; disp = 'F8.6'
#     name = 'slitsize_my'; format = '1E'; disp = 'F8.6'
#     name = 'slittilt_m'; format = '1E'; disp = 'F6.3'
#     name = 'slitsize_mr'; format = '1E'; disp = 'F8.6'
#     name = 'slitsize_mw'; format = '1E'; disp = 'F8.6'
#     name = 'slittype'; format = '9A'; disp = 'A9'
#     name = 'SELECT'; format = '1J'; null = -2147483647; disp = 'I11'
#     name = 'SECX1'; format = '1J'; null = -2147483647; disp = 'I11'
#     name = 'SECX2'; format = '1J'; null = -2147483647; disp = 'I11'
#     name = 'SECY1'; format = '1J'; null = -2147483647; disp = 'I11'
#     name = 'SECY2'; format = '1J'; null = -2147483647; disp = 'I11'
# )
# Objecto:      [ 23  44  69 117 138 162 188 278 312 340 391 422 455 477 513 541]
# RA:           [ 308.64221191  308.5758667   308.6144104   308.57006836  308.64971924
#   308.61755371  308.61776733  308.60577393  308.61273193  308.56143188
#   308.57867432  308.65136719  308.59536743  308.60784912  308.57302856
#   308.60922241]
# DEC:          [ 28.23370934  28.23719978  28.24090004  28.24753952  28.25247955
#   28.25674057  28.26140022  28.27685928  28.28113937  28.2849102
#   28.29171944  28.29636955  28.30186081  28.30677986  28.31340027
#   28.31936073]

# %% [markdown]
# Plot de RA(pixels) e DEC(pixels) (arquivo '2.fits')

# %%
# %matplotlib inline
x = data1.x_ccd
y = data1.y_ccd
plt.subplots(figsize=(10,10))
plt.plot(x,y,'ro'), plt.xlabel('RA(pixels) '), plt.ylabel('DEC(pixels)')
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False)
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.show()

# %% [markdown]
# Plot do arquivo '1.fits'. Como se pode  observar a imagem de baixo esta em pixels enquanato a imagem de acima esta em pixels  também. Assim que precisamos converter de pixels a RA e DEC.

# %%
# %matplotlib inline
fig1, ax1 = plt.subplots(1,1, figsize=(10,10))
plt.xlabel('RA(pixels) '), plt.ylabel('DEC(pixels)')
ax1.imshow(np.log(hdulist_1[1].data)).set_cmap('Greys')

# %% [markdown]
# Para  converter de pixels a cordeadas RAe DEC utilizaremos o pocote WCS ( world coordinate systems). Para  mais informação  vide o site https://github.com/astropy/astropy-api/blob/master/wcs_axes/wcs_api.md e também http://astropy.readthedocs.org/en/latest/wcs/

# %%
# %matplotlib inline

from astropy.wcs import WCS
from wcsaxes import WCSAxes

hdulist_1 = fits.open('1.fits')
hdulist_2 = fits.open('2.fits')

fig2 = plt.figure(figsize = (10,10))
ax2 = WCSAxes(fig2, [0.1, 0.1, 0.8, 0.8], wcs=WCS(hdulist_1[1].header))
fig2.add_axes(ax2)

ax2.imshow(np.log(hdulist_1[1].data), origin='lower').set_cmap('Greys')
ax2.plot(hdulist_2[1].data['x_ccd'],hdulist_2[1].data['y_ccd'],'or')
fig2.savefig('campo.png')

# %% [markdown]
# ###### ESPECTROS

# %% [markdown]
# Como  já foi dito anteriormente  o arquivo 2.fits  contém dados, entre estes dados estão espectros mas estos estão em pixels e não em comprimento de onda, assim que será  necessário fazer a transformação a  comprimento de onda em amstroms (A), para esto  veremos dois  método: primeiro utilizado somente  o python e alguns pacotes. O segundo método é utilizando WCS ( world coordinate systems).

# %% [markdown]
# * Primeiro método: Este é  um exemplo para o objeto 5 da lista. (Para mais  informação de este método  vide o site http://nbviewer.ipython.org/github/gabraganca/S4/blob/master/notebooks/load-spectrum-FITS.ipynb)

# %%
# %matplotlib inline

#impostando a o arquivo .fits

origin_spec = pyfits.open('2.fits')

# numero do espectro
origin_flux = origin_spec[5].data

# informacoes do esptro aser covertido
origin_spec[5].header[0:11]

# do anterior os tres ultimos valores
ref_pixel = origin_spec[5].header['CRPIX1']
coord_ref_pixel = origin_spec[5].header['CRVAL1']
wave_pixel = origin_spec[5].header['CDELT1']

#funcao wavelength

def get_wstart(ref, wave_ref, wave_per_pixel):
     return wave_ref - ((ref-1) * wave_per_pixel)

wstart = get_wstart(ref_pixel, coord_ref_pixel, wave_pixel)
print 'Starting wavelength = {}'.format(wstart)

#funcao para escrever uma variedade de comprimentos de onda para nosso array de fluxo.
def get_wavelength(start_wave, wave_per_pixel, size):
    return np.array([start_wave + i*wave_per_pixel for i in range(size)])
wave_array = get_wavelength(wstart, wave_pixel, len(origin_flux))
print wave_array

#funcao que envolve as funcoes anteriores:
def load_spectrum(fname):
    # Load espectro
    spec_FITS = pyfits.open(fname)
    #Load fluxo
    flux = spec_FITS[5].data
    
    #obtencao de parametros para a determinacao de comprimento de onda a partir do Header
    ref_pixel = spec_FITS[5].header['CRPIX1']       #pixel
    coord_ref_pixel = spec_FITS[5].header['CRVAL1'] #Wavelength pixel
    wave_pixel = spec_FITS[5].header['CDELT1']      #Wavelength* pixel
    
    #comprimiento de onda inicial
    wstart = get_wstart(ref_pixel, coord_ref_pixel, wave_pixel)
    
    #Obtain array of wavelength
    wave = get_wavelength(wstart, wave_pixel, len(flux))
    
    return np.dstack((wave, flux))[0]
full_spec = load_spectrum('2.fits')
print full_spec
print "Type is", type(full_spec)
print "Dimension is", full_spec.shape
plt.subplots(figsize=(8,8))
plt.plot(full_spec[:, 0], full_spec[:, 1], 'r-')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.show()
# Out:
# Starting wavelength = 3707.88964844
# [ 3707.88964844  3708.8102439   3709.73083937 ...,  6566.33857375
#   6567.25916922  6568.17976469]
# [[ 3707.88964844    83.20265198]
#  [ 3708.8102439     79.8319397 ]
#  [ 3709.73083937    79.92524719]
#  ...,
#  [ 6566.33857375  5516.04394531]
#  [ 6567.25916922  5732.45703125]
#  [ 6568.17976469  5836.11132812]]
# Type is <type 'numpy.ndarray'>
# Dimension is (3108, 2)

# %% [markdown]
# * Segundo método: Este método  consiste em utilizar o pacote WCS ( world coordinate systems). vide o site https://github.com/astropy/astropy-api/blob/master/wcs_axes/wcs_api.md

# %%
# %matplotlib inline
origin_spec[1].header[0:11]
print origin_spec[1].header['NAXIS']
fig3, ax3 = plt.subplots(1, 1, figsize=(12,10))
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
def pix2ang(hdu, ax):
    wcs = WCS(hdu.header)
    index = np.arange(hdu.header['NAXIS1'])
    angs = wcs.wcs_pix2world(index[:,np.newaxis], 0)
    angs = angs.flatten()
    ax.plot(angs, hdu.data, '-')
    
for i in np.array(xrange(13))+2:
    pix2ang(hdulist_2[i],ax3)
    
fig3.savefig('example3.png')
# Out:
# 2

# %% [markdown]
# * V0table

# %% [markdown]
# Agora   vamos a salvar  os dados  do aquivo 2.fits em  formato V0tableAgora   vamos a salvar  os dados  do aquivo 2.fits em  formato V0table. (vide o site: https://github.com/astropy/astropy/blob/master/docs/io/votable/index.rst, https://github.com/astropy/astropy/blob/master/docs/io/votable/index.rst e https://astropy.readthedocs.org/en/v0.3/io/votable/index.html)

# %%
# %matplotlib inline

from astropy.io.votable.tree import VOTableFile, Resource, Table, Field
hdulist_2 = pyfits.open('2.fits')
myData = hdulist_2[1].data

nRows = len(myData)
nCols = len(myData[0])

idd = myData.ID
ra = myData.RA
dec = myData.DEC

# Create a new VOTable file...
votable = VOTableFile()

# 
resource = Resource()
votable.resources.append(resource)

# Define some fields
table = Table(votable)
resource.tables.append(table)

table.fields.extend([
        Field(votable, name="ID", datatype="int"),
        Field(votable, name="RA", datatype="double", unit="deg" ),
        Field(votable, name="DEC", datatype="double", unit="deg")])

# Now, use those field definitions to create the numpy record arrays, with
# the given number of rows
table.create_arrays(nRows)

# 
print 'saida_table'
for i in range(nRows):
    table.array[i] = (idd[i], ra[i], dec[i])
    print 'objeto, RA, DEC =',table.array[i]

# Now write the whole thing to a file.
# Note, we have to use the top-level votable file object
votable.to_xml("VOtable.xml")
# Out:
# saida_table
# objeto, RA, DEC = (23, 308.6422119140625, 28.23370933532715)
# objeto, RA, DEC = (44, 308.57586669921875, 28.237199783325195)
# objeto, RA, DEC = (69, 308.6144104003906, 28.24090003967285)
# objeto, RA, DEC = (117, 308.570068359375, 28.247539520263672)
# objeto, RA, DEC = (138, 308.64971923828125, 28.252479553222656)
# objeto, RA, DEC = (162, 308.6175537109375, 28.25674057006836)
# objeto, RA, DEC = (188, 308.6177673339844, 28.26140022277832)
# objeto, RA, DEC = (278, 308.60577392578125, 28.276859283447266)
# objeto, RA, DEC = (312, 308.61273193359375, 28.281139373779297)
# objeto, RA, DEC = (340, 308.5614318847656, 28.284910202026367)
# objeto, RA, DEC = (391, 308.57867431640625, 28.291719436645508)
# objeto, RA, DEC = (422, 308.6513671875, 28.296369552612305)
# objeto, RA, DEC = (455, 308.5953674316406, 28.301860809326172)
# objeto, RA, DEC = (477, 308.60784912109375, 28.306779861450195)
# objeto, RA, DEC = (513, 308.5730285644531, 28.313400268554688)
# objeto, RA, DEC = (541, 308.6092224121094, 28.319360733032227)

# %% [markdown]
# * A saida deste programa tem uma extenção '.xml'

# %% [markdown]
# ###### Bibliografia

# %% [markdown]
# https://pythonhosted.org/pyfits/users_guide/users_tutorial.html \\
# https://github.com/astropy/astropy-api/blob/master/wcs_axes/wcs_api.md \\
# https://github.com/astropy/astropy/blob/master/docs/io/votable/index.rst \\
# https://github.com/astropy/astropy-api/blob/master/wcs_axes/wcs_api.md \\
# http://astropy.readthedocs.org/en/latest/wcs/
